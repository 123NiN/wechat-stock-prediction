# %%
data=pd.read_csv("data_need1.csv")
data.loc[1,'pred']=0
data['pred_result']=0
for i in range(51,608):
    if data.loc[i+1,'open']-data.loc[i,'open']>0:
        data.loc[i,'pred_result']=1
    else:
        data.loc[i,'pred_result']=0
data

def function1(a,b,c):
    sum=b-a
    if c in [0,1,2]and sum>=0:
        return 0
    elif c in [0,1,2]and sum<0:
        return 1
    elif c in [3,4,5]and sum>=0:
        return 1
    elif c in [3,4,5] and sum<0:
        return 0
# Out:
#      Unnamed: 0        date  open  pred  pred_result
# 0             0  2019-02-25  6.18   NaN            0
# 1             1  2019-02-26  6.23   0.0            0
# 2             2  2019-02-27  6.08   NaN            0
# 3             3  2019-02-28  6.57   NaN            0
# 4             4  2019-03-01  6.50   NaN            0
# ..          ...         ...   ...   ...          ...
# 605         605  2021-08-17  4.20   2.0            0
# 606         606  2021-08-18  4.16   2.0            1
# 607         607  2021-08-19  4.23   2.0            1
# 608         608  2021-08-20  4.29   2.0            0
# 609         609  2021-08-23  4.15   2.0            0
#
# [610 rows x 5 columns]

# %%
import pandas as pd
data=pd.read_csv("1_st688148.csv")

for i in range(0,100):
    data.iloc[i]['result']=int(0)
    if(data.iloc[i]['结果'][1]=='1'):
        data.iloc[i]['result']=int(1)
    else:
        data.iloc[i]['result']=int(-1)
        
data    
    #
    #data.iloc[i]['结果']=int(data.iloc[i]['结果'][1])
# Out:
# <ipython-input-24-9c850aed7e5e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.iloc[i]['result']=int(0)
# <ipython-input-24-9c850aed7e5e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.iloc[i]['result']=int(1)
# <ipython-input-24-9c850aed7e5e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.iloc[i]['result']=int(-1)
#     Unnamed: 0      代号                   时间  \
# ...

# %%
data['result']=0
data
# Out:
#     Unnamed: 0      代号                   时间  \
# 0            0  688148  2021-08-14 08:13:56
# 1            1  688148  2021-08-13 11:37:42
# 2            2  688148  2021-08-13 08:12:17
# 3            3  688148  2021-08-12 08:19:15
# 4            4  688148  2021-08-12 08:08:13
# ..         ...     ...                  ...
# 95          95  688148  2021-01-03 08:55:59
# 96          96  688148  2021-01-01 07:01:53
# 97          97  688148  2020-12-31 14:45:19
# 98          98  688148  2020-12-31 13:04:52
# 99          99  688148  2020-12-31 13:04:25
#
#                                                    链接  \
# 0   http://stock.eastmoney.com/a/20210814204624987...
# 1   http://finance.eastmoney.com/a/202108132044861...
# 2   http://stock.eastmoney.com/a/20210813204421307...
# 3   http://finance.eastmoney.com/a/202108122042216...
# 4   http://stock.eastmoney.com/a/20210812204216342...
# ..                                                ...
# ...

# %%
data[0,'result']=1
data.drip(data.columns[-2:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-aa45eb273a94> in <module>
#       1 data[0,'result']=1
# ----> 2 data.drip(data.columns[-2:])
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'drip'

# %%
type(data.loc[1,6])
data.loc[1,6]
for i in data['结果']:
    if i[1]==1:
        i=int(1)
    else:
        i=int(-1)

# %%
#data.loc[1,'结果']=1
data
for i in range(0,100):
    if(data.loc[i,'结果'][1]=='1'):
        data.loc[i,'结果']=int(1)
    else:
        data.loc[i,'结果']=int(-1)

# %%
data.to_csv("result.csv")

# %%
import pandas as pd
data=pd.read_csv("result.csv")
time=[]
for i in data['时间']:
    if i[:9] not in time:
        time.append(i[:9])
    else:
        pass

# %%
time
# Out:
# ['2021-08-1',
#  '2021-08-0',
#  '2021-07-3',
#  '2021-07-2',
#  '2021-07-1',
#  '2021-07-0',
#  '2021-06-1',
#  '2021-06-0',
#  '2021-05-2',
#  '2021-05-1',
#  '2021-04-0',
#  '2021-03-2',
#  '2021-03-1',
#  '2021-03-0',
#  '2021-02-2',
#  '2021-02-0',
#  '2021-01-2',
#  '2021-01-0',
#  '2020-12-3']

# %%
data2=pd.read_csv("pd600050.csv")
cuseor=0
print(time[0]>'2021-08-15')
# Out:
# False

# %%
import pandas as pd
test=pd.DataFrame()
test['date']=''
test['sum']=int(0)
test
for i in range(0,len(time)):
    test.loc[i,'date']=time[i]
test
# Out:
#          date  sum
# 0   2021-08-1  NaN
# 1   2021-08-0  NaN
# 2   2021-07-3  NaN
# 3   2021-07-2  NaN
# 4   2021-07-1  NaN
# 5   2021-07-0  NaN
# 6   2021-06-1  NaN
# 7   2021-06-0  NaN
# 8   2021-05-2  NaN
# 9   2021-05-1  NaN
# 10  2021-04-0  NaN
# 11  2021-03-2  NaN
# 12  2021-03-1  NaN
# 13  2021-03-0  NaN
# 14  2021-02-2  NaN
# 15  2021-02-0  NaN
# 16  2021-01-2  NaN
# 17  2021-01-0  NaN
# 18  2020-12-3  NaN

# %%
data1=pd.read_csv("end1.csv")
data1.loc[199,'date']
test['sum']=0
test['positive']=0
for j in range(0,len(time)):
    for i in range(0,100):
        if test.loc[j,'date']<result.loc[i,'时间']:
            test.loc[j,'positive']+=int(result.loc[i,'结果'])
            test.loc[j,'sum']+=1
test
# Out:
#          date  sum  positive
# 0   2021-08-1    8         8
# 1   2021-08-0   40        26
# 2   2021-07-3   42        28
# 3   2021-07-2   58        36
# 4   2021-07-1   63        39
# 5   2021-07-0   70        42
# 6   2021-06-1   71        41
# 7   2021-06-0   73        41
# 8   2021-05-2   76        44
# 9   2021-05-1   78        46
# 10  2021-04-0   79        47
# 11  2021-03-2   80        48
# 12  2021-03-1   81        49
# 13  2021-03-0   82        50
# 14  2021-02-2   84        48
# 15  2021-02-0   86        48
# 16  2021-01-2   89        49
# 17  2021-01-0   97        45
# 18  2020-12-3  100        46

# %%
data=pd.read_csv("end2.csv")
data['%']=0
for i in range(0,len(time)):
    data.loc[i,'%']=data.loc[i,'positive']/data.loc[i,'sum']
data.to_csv("end2.csv")

# %%
time
# Out:
# ['2021-08-1',
#  '2021-08-0',
#  '2021-07-3',
#  '2021-07-2',
#  '2021-07-1',
#  '2021-07-0',
#  '2021-06-1',
#  '2021-06-0',
#  '2021-05-2',
#  '2021-05-1',
#  '2021-04-0',
#  '2021-03-2',
#  '2021-03-1',
#  '2021-03-0',
#  '2021-02-2',
#  '2021-02-0',
#  '2021-01-2',
#  '2021-01-0',
#  '2020-12-3']
